# %% [markdown]
# <a href="https://colab.research.google.com/github/preethadk11/30-Days-Of-Python-challenge/blob/main/30_Days_Of_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Day1 Exercise**

# %%
import sys
print(sys.version)
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %%
print(3+4);print(3-4);print(3*4);print(int(3/4));print(3%4);print(3//4)
# Out:
# 7
# -1
# 12
# 0
# 3
# 0

# %%
print("Preetha catherin")
print("India")
print("I am enjoying 30 days of Python")
# Out:
# Preetha catherin
# India
# I am enjoying 30 days of Python

# %%
print(type(10));print(type(9.8));print(type(3.14));print(type(4-4j));print(type(['asabeh','python','finland']));print(type('Preetha'))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'float'>
# <class 'complex'>
# <class 'list'>
# <class 'str'>

# %% [markdown]
# **Euclidian distance**

# %%
import math as m
#given (2,3) and (10,8)
x1=2;y1=3;x2=10;y2=8
d=((x2-x1)**2)+((y2-y1)**2)
result=m.sqrt(d)
print(result)
# Out:
# 9.433981132056603

# %% [markdown]
# **Day2Exercise**

# %%
#Day 2: 30 Days of python programming
first_name='Preetha'
last_name="catherin"
full_name='Preetha Catherin'
country='India'
city='Karaikal'
age=19
year=2025
is_married=False
is_true='I am enjoying it'
is_light_on='No'
rigth='Yes';left='no'
print(type(first_name))
print(len(first_name))
print(len(first_name)==len(last_name))
num_one=5;num_two=4
total=num_one+num_two
exp=num_one**num_two
print(total)
print(exp)
radius=int(input("Enter radius:"))
area=3.14*radius*radius
print(area)
circum=2*3.14*radius
print(circum)
help('keywords')
# Out:
# <class 'str'>
# 7
# False
# 9
# 625
# Enter radius:4
# 50.24
# 25.12
#
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not
